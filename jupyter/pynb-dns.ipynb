# %%
# DATAOUTDIR="data-dns-1-1"
# DATADIR= "../passive-2016/equinix-chicago/20160121-130000.UTC"  #"../tmp/data"
# DATA_SUFFIX="pcap.gz"
DATAOUTDIR="data-dns-dsr6059"
DATADIR="/home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data"
DATA_SUFFIX=".erf"

import pandas as pd
import os
import  multiprocessing as mp
import subprocess
# d = pd.read_csv("../tmp/test2all.dat",error_bad_lines =False,names=['time','src','dst','proto', 'vol','src_port','dst_port'])

global DbgV

# tshark -r test.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r test.pcap.gz -Y tcp -Tfields -e "ip.src" -e "ip.dst" -Taggregator=,

def worker(f,ii):
    # global DbgV
    # d = pd.read_csv(DATADIR+"/"+f, error_bad_lines =False,names=['time','src','dst','proto', 'vol','src_port','dst_port'])
    # sld=d[(d['proto']=='UDP')]
    # DbgV=d
    # sld['vol']=sld['vol'].astype(int)
    # grouped = sld['vol'].groupby(sld['src_port'])
    # ss = grouped.sum()
    print(f)
    print(ii)
    cmd='tshark -r %s -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,'%(DATADIR+"/"+f)
    print(cmd)
    p = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE) 
    print("popen")
    d = pd.read_csv(p.stdout, error_bad_lines =False,names=['src','dst','iplen','src_port','dst_port'],dtype=str)
    print("read")
    p.wait()
    print("wait")
    sld=d[(d['src_port']=='53')| (d['dst_port']=='53')]
    sld.to_csv(DATAOUTDIR+"/"+str(ii)+".csv",index=False)
    print("to_csv")

p = mp.Pool(processes=4)

ii=0
for root, dirs, files in os.walk(DATADIR):
    print(root)
    print(dirs)
    print(files)
    for f in files:
        #p.apply_async(worker,(f,ii))
        if f.endswith(DATA_SUFFIX):
            p.apply_async(worker,(f,ii))
            ii+=1

p.close()
p.join()
# Out:
# 20130617-221839-00015200-r.full.erf
# 20130617-215245-00015186-r.full.erf
# 20130617-221439-00015198-r.full.erf
# 20130617-220941-00015195-r.full.erf
# 0
# 1
# 3
# 2
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-221839-00015200-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-215245-00015186-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-221439-00015198-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-220941-00015195-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# popen
# popen
# popen
# /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data
# []
# ['20130617-221839-00015200-r.full.erf', '20130617-215245-00015186-r.full.erf', '20130617-221439-00015198-r.full.erf', '20130617-220941-00015195-r.full.erf', '.sha1sum', '20130617-220756-00015194-r.full.erf', '20130617-221119-00015196-r.full.erf', '20130617-220252-00015191-r.full.erf', '20130617-222035-00015201-r.full.erf', '20130617-215926-00015189-r.full.erf', '20130617-222237-00015203-r.full.erf', '20130617-221259-00015197-r.full.erf', '20130617-215723-00015188-r.full.erf', '20130617-221625-00015199-r.full.erf', '20130617-215500-00015187-r.full.erf', '20130617-222355-00015204-r.full.erf', '20130617-220123-00015190-r.full.erf', '20130617-222216-00015202-r.full.erf', '20130617-220612-00015193-r.full.erf', '20130617-220432-00015192-r.full.erf']
# read
# wait
# to_csv
# 20130617-220756-00015194-r.full.erf
# 4
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-220756-00015194-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-221119-00015196-r.full.erf
# 5
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-221119-00015196-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-220252-00015191-r.full.erf
# 6
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-220252-00015191-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-222035-00015201-r.full.erf
# 7
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-222035-00015201-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-215926-00015189-r.full.erf
# 8
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-215926-00015189-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-222237-00015203-r.full.erf
# 9
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-222237-00015203-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-221259-00015197-r.full.erf
# 10
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-221259-00015197-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-215723-00015188-r.full.erf
# 11
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-215723-00015188-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-221625-00015199-r.full.erf
# 12
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-221625-00015199-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-215500-00015187-r.full.erf
# 13
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-215500-00015187-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-222355-00015204-r.full.erf
# 14
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-222355-00015204-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-220123-00015190-r.full.erf
# 15
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-220123-00015190-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-222216-00015202-r.full.erf
# 16
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-222216-00015202-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-220612-00015193-r.full.erf
# 17
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-220612-00015193-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# 20130617-220432-00015192-r.full.erf
# 18
# tshark -r /home/pcl/8LStudentYuHaitao/DSR-6059/DoS_DNS_amplification-20130617/data/20130617-220432-00015192-r.full.erf -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
