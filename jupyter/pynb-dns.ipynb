# %%
DATAOUTDIR="data-dns-1-1"
DATADIR= "../passive-2016/equinix-chicago/20160121-130000.UTC"  #"../tmp/data"

import pandas as pd
import os
import  multiprocessing as mp
import subprocess
# d = pd.read_csv("../tmp/test2all.dat",error_bad_lines =False,names=['time','src','dst','proto', 'vol','src_port','dst_port'])

global DbgV

# tshark -r test.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r test.pcap.gz -Y tcp -Tfields -e "ip.src" -e "ip.dst" -Taggregator=,

def worker(f,ii):
    # global DbgV
    # d = pd.read_csv(DATADIR+"/"+f, error_bad_lines =False,names=['time','src','dst','proto', 'vol','src_port','dst_port'])
    # sld=d[(d['proto']=='UDP')]
    # DbgV=d
    # sld['vol']=sld['vol'].astype(int)
    # grouped = sld['vol'].groupby(sld['src_port'])
    # ss = grouped.sum()
    print(f)
    print(ii)
    cmd='tshark -r %s -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,'%(DATADIR+"/"+f)
    print(cmd)
    p = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE) 
    print("popen")
    d = pd.read_csv(p.stdout, error_bad_lines =False,names=['src','dst','iplen','src_port','dst_port'],dtype=str)
    print("read")
    p.wait()
    print("wait")
    sld=d[(d['src_port']=='53')| (d['dst_port']=='53')]
    sld.to_csv(DATAOUTDIR+"/"+str(ii)+".csv",index=False)
    print("to_csv")

p = mp.Pool(processes=24)

ii=0
for root, dirs, files in os.walk(DATADIR):
    print(root)
    print(dirs)
    print(files)
    for f in files:
        #p.apply_async(worker,(f,ii))
        if f[-7:]=="pcap.gz":
            p.apply_async(worker,(f,ii))
            ii+=1

p.close()
p.join()
# Out:
# equinix-chicago.dirA.20160121-134200.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-134000.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-130800.UTC.anon.pcap.gz
# 0
# 1
# equinix-chicago.dirB.20160121-134500.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-133900.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-135500.UTC.anon.pcap.gz
# 3
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# equinix-chicago.dirA.20160121-130400.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-132300.UTC.anon.pcap.gz
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# equinix-chicago.dirB.20160121-131000.UTC.anon.pcap.gz
# 4
# equinix-chicago.dirB.20160121-130700.UTC.anon.pcap.gz
# 2
# 5
# equinix-chicago.dirA.20160121-135800.UTC.anon.pcap.gz
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# 6
# 7
# 8
# equinix-chicago.dirA.20160121-134500.UTC.anon.pcap.gz
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# equinix-chicago.dirB.20160121-135100.UTC.anon.pcap.gz
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# 9
# equinix-chicago.dirA.20160121-131600.UTC.anon.pcap.gz
# 10
# equinix-chicago.dirA.20160121-135400.UTC.anon.pcap.gz
# equinix-chicago.dirA.20160121-130500.UTC.anon.pcap.gz
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# equinix-chicago.dirA.20160121-133700.UTC.anon.pcap.gz
# 15
# equinix-chicago.dirA.20160121-130100.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-131500.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-130000.UTC.anon.pcap.gz
# 17
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# 16
# 19
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# 18
# 20
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# 21
# 22
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# 23
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# popen
# equinix-chicago.dirB.20160121-134900.UTC.anon.pcap.gz
# 11
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# equinix-chicago.dirA.20160121-132100.UTC.anon.pcap.gz
# equinix-chicago.dirB.20160121-133600.UTC.anon.pcap.gz
# equinix-chicago.dirA.20160121-125911.UTC.anon.pcap.gz
# 12
# 13
# 14
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-125911.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# popen
# popen
# ../passive-2016/equinix-chicago/20160121-130000.UTC
# []
# ['equinix-chicago.dirB.20160121-134500.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-133100.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-135800.UTC.anon.times.gz', 'equinix-chicago.dirA.20160121-134200.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-132800.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-134500.UTC.anon.pcap.gz.json', 'equinix-chicago.dirA.20160121-135400.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-134000.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-133900.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-131700.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-133700.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-133600.UTC.anon.pcap.gz.json', 'equinix-chicago.dirB.20160121-130800.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-134500.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-131600.UTC.anon.pcap.gz.json', 'equinix-chicago.dirB.20160121-135500.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-132600.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-131700.UTC.anon.times.gz', 'equinix-chicago.dirA.20160121-130400.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-131900.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-132300.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-130500.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-130000.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-131000.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-131600.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-133900.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-130700.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-132900.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-131600.UTC.anon.times.gz', 'equinix-chicago.dirA.20160121-135800.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-133700.UTC.anon.times.gz', 'equinix-chicago.dirA.20160121-134800.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-135900.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-130800.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-130100.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-134900.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-132100.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-131900.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-132100.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-133600.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-125911.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-134200.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-134500.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-140100.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-130300.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-130600.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-133300.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-132400.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-130700.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-132700.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-131900.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-132500.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-125911.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-130900.UTC.anon.times.gz', 'equinix-chicago.dirA.20160121-134500.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-131600.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-135100.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-134100.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-133800.UTC.anon.times.gz', 'equinix-chicago.dirA.20160121-140000.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-130500.UTC.anon.pcap.gz', 'equinix-chicago.dirA.20160121-135000.UTC.anon.times.gz', 'equinix-chicago.dirA.20160121-135400.UTC.anon.pcap.gz', 'equinix-chicago.dirB.20160121-130000.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-131500.UTC.anon.times.gz', 'equinix-chicago.dirB.20160121-131100.UTC.anon.pcap.stats', 'equinix-chicago.dirB.20160121-134600.UTC.anon.pcap.stats', 'equinix-chicago.dirA.20160121-133700.UTC.anon.pcap.gz', 'equinix-chicago.d ...
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-130000.UTC.anon.pcap.gz
# 24
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-140000.UTC.anon.pcap.gz
# 25
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-140000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-130100.UTC.anon.pcap.gz
# 26
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-131800.UTC.anon.pcap.gz
# 27
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132400.UTC.anon.pcap.gz
# 28
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135000.UTC.anon.pcap.gz
# 29
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-130900.UTC.anon.pcap.gz
# 30
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131300.UTC.anon.pcap.gz
# 31
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132000.UTC.anon.pcap.gz
# 32
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133300.UTC.anon.pcap.gz
# 33
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133500.UTC.anon.pcap.gz
# 34
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-134800.UTC.anon.pcap.gz
# 35
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134000.UTC.anon.pcap.gz
# 36
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131000.UTC.anon.pcap.gz
# 37
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-134400.UTC.anon.pcap.gz
# 38
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-130600.UTC.anon.pcap.gz
# 39
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133800.UTC.anon.pcap.gz
# 40
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-134700.UTC.anon.pcap.gz
# 41
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133700.UTC.anon.pcap.gz
# 42
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131100.UTC.anon.pcap.gz
# 43
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132900.UTC.anon.pcap.gz
# 44
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-140100.UTC.anon.pcap.gz
# 45
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-140100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132900.UTC.anon.pcap.gz
# 46
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-131200.UTC.anon.pcap.gz
# 47
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-131600.UTC.anon.pcap.gz
# 48
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-130900.UTC.anon.pcap.gz
# 49
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131900.UTC.anon.pcap.gz
# 50
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135400.UTC.anon.pcap.gz
# 51
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132100.UTC.anon.pcap.gz
# 52
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135500.UTC.anon.pcap.gz
# 53
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133100.UTC.anon.pcap.gz
# 54
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-140200.UTC.anon.pcap.gz
# 55
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-140200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-134300.UTC.anon.pcap.gz
# 56
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135700.UTC.anon.pcap.gz
# 57
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-130500.UTC.anon.pcap.gz
# 58
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133600.UTC.anon.pcap.gz
# 59
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132000.UTC.anon.pcap.gz
# 60
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133800.UTC.anon.pcap.gz
# 61
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133200.UTC.anon.pcap.gz
# 62
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134400.UTC.anon.pcap.gz
# 63
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-131300.UTC.anon.pcap.gz
# 64
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-130600.UTC.anon.pcap.gz
# 65
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135600.UTC.anon.pcap.gz
# 66
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-130200.UTC.anon.pcap.gz
# 67
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-131900.UTC.anon.pcap.gz
# 68
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-130200.UTC.anon.pcap.gz
# 69
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133100.UTC.anon.pcap.gz
# 70
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133500.UTC.anon.pcap.gz
# 71
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132500.UTC.anon.pcap.gz
# 72
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135000.UTC.anon.pcap.gz
# 73
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-130700.UTC.anon.pcap.gz
# 74
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135800.UTC.anon.pcap.gz
# 75
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-130400.UTC.anon.pcap.gz
# 76
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134800.UTC.anon.pcap.gz
# 77
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132600.UTC.anon.pcap.gz
# 78
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132600.UTC.anon.pcap.gz
# 79
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133200.UTC.anon.pcap.gz
# 80
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131700.UTC.anon.pcap.gz
# 81
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134900.UTC.anon.pcap.gz
# 82
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-131100.UTC.anon.pcap.gz
# 83
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132400.UTC.anon.pcap.gz
# 84
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131500.UTC.anon.pcap.gz
# 85
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133300.UTC.anon.pcap.gz
# 86
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-130800.UTC.anon.pcap.gz
# 87
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134700.UTC.anon.pcap.gz
# 88
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-130300.UTC.anon.pcap.gz
# 89
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-130300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132300.UTC.anon.pcap.gz
# 90
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135100.UTC.anon.pcap.gz
# 91
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-140000.UTC.anon.pcap.gz
# 92
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-140000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# to_csv
# equinix-chicago.dirB.20160121-131700.UTC.anon.pcap.gz
# 93
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131800.UTC.anon.pcap.gz
# 94
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132200.UTC.anon.pcap.gz
# 95
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135300.UTC.anon.pcap.gz
# 96
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-140100.UTC.anon.pcap.gz
# 97
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-140100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135200.UTC.anon.pcap.gz
# 98
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-130300.UTC.anon.pcap.gz
# 99
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-130300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135700.UTC.anon.pcap.gz
# 100
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133000.UTC.anon.pcap.gz
# 101
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133900.UTC.anon.pcap.gz
# 102
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# to_csv
# equinix-chicago.dirB.20160121-135300.UTC.anon.pcap.gz
# 103
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-134200.UTC.anon.pcap.gz
# 104
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-133400.UTC.anon.pcap.gz
# 105
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-133400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132800.UTC.anon.pcap.gz
# 106
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132200.UTC.anon.pcap.gz
# 107
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135600.UTC.anon.pcap.gz
# 108
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-132700.UTC.anon.pcap.gz
# 109
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135641.UTC.anon.pcap.gz
# 110
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135641.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-134100.UTC.anon.pcap.gz
# 111
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-125911.UTC.anon.pcap.gz
# 112
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-125911.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132500.UTC.anon.pcap.gz
# 113
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132500.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134600.UTC.anon.pcap.gz
# 114
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# to_csv
# equinix-chicago.dirB.20160121-132800.UTC.anon.pcap.gz
# 115
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-132800.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133000.UTC.anon.pcap.gz
# 116
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133000.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# to_csv
# equinix-chicago.dirB.20160121-131400.UTC.anon.pcap.gz
# 117
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-131400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-134600.UTC.anon.pcap.gz
# 118
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-134600.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-140200.UTC.anon.pcap.gz
# 119
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-140200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131200.UTC.anon.pcap.gz
# 120
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-131400.UTC.anon.pcap.gz
# 121
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-131400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-135900.UTC.anon.pcap.gz
# 122
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-135900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134100.UTC.anon.pcap.gz
# 123
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134100.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-134300.UTC.anon.pcap.gz
# 124
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-134300.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135200.UTC.anon.pcap.gz
# 125
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135200.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirB.20160121-135900.UTC.anon.pcap.gz
# 126
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirB.20160121-135900.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-133400.UTC.anon.pcap.gz
# 127
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-133400.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# equinix-chicago.dirA.20160121-132700.UTC.anon.pcap.gz
# 128
# tshark -r ../passive-2016/equinix-chicago/20160121-130000.UTC/equinix-chicago.dirA.20160121-132700.UTC.anon.pcap.gz -Y udp -Tfields -e "ip.src" -e "ip.dst" -e "ip.len" -e "udp.srcport"  -e "udp.dstport" -Eseparator=,
# popen
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
# read
# wait
# to_csv
